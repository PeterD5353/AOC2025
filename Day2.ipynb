# %% [markdown]
# Part 1

# %%
input = ['7777742220-7777814718',
'3201990-3447830',
'49-86',
'653243-683065',
'91-129',
'24-41',
'1-15',
'2678-4638',
'1407-2511',
'221-504',
'867867-942148',
'1167452509-1167622686',
'9957459726-9957683116',
'379068-535983',
'757-1242',
'955118-1088945',
'297342-362801',
'548256-566461',
'4926-10075',
'736811-799457',
'1093342-1130060',
'620410-651225',
'65610339-65732429',
'992946118-993033511',
'5848473-5907215',
'17190619-17315301',
'203488-286290',
'15631-36109',
'5858509282-5858695889',
'87824047-87984031',
'1313113913-1313147594',
'795745221-795825571',
'46303-100636',
'4743038-4844422']

# %%
input[0]

first, second = input[0].split(sep='-')
print(first)
print(second)
first = int(first)
second = int(second)
# Out:
# 7777742220
# 7777814718

# %%
# calculate the invalid codes and add to the total      
total = 0
for i in range(first, second + 1):
    string = str(i)
    length = len(string)
    if string[length:] == string[:length]:
        print(i)
        total += i

# %%
total = 0
for r in range(len(input)):
    first, second = input[r].split(sep='-')
    first = int(first)
    second = int(second)

    for i in range(first, second + 1):
        string = str(i)
        length = len(string)
        if (length % 2) == 0:
            half = int(length / 2)
            if string[half:] == string[:half]:
                total += i

# %%
print(total)
# Out:
# 44487518055

# %% [markdown]
# Part 2

# %%
total3 = 0
mine2 = []
for r in range(len(input)):
    first, second = input[r].split(sep='-')
    first = int(first)
    second = int(second)

    for i in range(first, second + 1):
        string = str(i)
        length = len(string)
        for s in range(1, int(length / 2) + 1):
            if length % s == 0:
                substring = string[:s]
                if string == substring * int((length / s)):
                    total3 += i 
                    mine2.append(int(string))
                    break

# %%
print(total3)
# Out:
# 53481866137
